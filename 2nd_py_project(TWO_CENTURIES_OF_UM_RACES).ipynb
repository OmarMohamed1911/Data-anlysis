# %%
#link of the Data set https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/discussion/420633

# %%
#Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading the data

# %%
df = pd.read_csv(r'D:\Data Analyst projects\Python projects\2nd project\TWO_CENTURIES_OF_UM_RACES.csv')
df.head(10)
# Out:
# C:\Users\HP.SXTO9\AppData\Local\Temp\ipykernel_12788\3057815156.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'D:\Data Analyst projects\Python projects\2nd project\TWO_CENTURIES_OF_UM_RACES.csv')
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# ...

# %%
df[df['Event name'].str.contains('USA')]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#Clean up data

# %%
#Only want USA races, 50k or 50 mi, 2020

# %%
#Step 1 show 50k or 50 mi
#50KM 
#50mi

# %%
df[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Compaine 50k/50mi with isin

# %%
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] ==2020) ]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name']== 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(USA)').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)== 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Compaine all filters together

# %%
df2 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] ==2020) & (df['Event name'].str.contains('USA'))]
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.shape
# Out:
# (26524, 13)

# %%
#Remove (USA) from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26524, dtype: object

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\HP.SXTO9\AppData\Local\Temp\ipykernel_12788\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Clean up athlete age

# %%
df2['athlete_age'] = 2020 - df2['Athlete year of birth']
df2['athlete_age']
# Out:
# C:\Users\HP.SXTO9\AppData\Local\Temp\ipykernel_12788\922506428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 - df2['Athlete year of birth']
# 2539945    29.0
# 2539946    39.0
# 2539947    21.0
# 2539948    37.0
# 2539949    43.0
#            ...
# 2760957    62.0
# 2760958    43.0
# 2760959    58.0
# 2760960    39.0
# 2760961    40.0
# Name: athlete_age, Length: 26524, dtype: float64

# %%
#Remove h from athlete prformance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\HP.SXTO9\AppData\Local\Temp\ipykernel_12788\2477507555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
#Drop columns: Athlete club, Athlete country, Athlete year of birth, Athlete age category

# %%
df2.drop(columns = ['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], inplace= True)
df2.head()
# Out:
# C:\Users\HP.SXTO9\AppData\Local\Temp\ipykernel_12788\4085982995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns = ['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], inplace= True)
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  235
# dtype: int64

# %%
df2[df2['athlete_age'].isna()==1]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2 =df2.dropna()

# %%
df2.shape
# Out:
# (26289, 10)

# %%
#check for dupes

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
#Reset index

# %%
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 26284           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26285           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26286           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26287           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26288           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
#Rename columns

# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int32

# %%
df2.rename(columns = {'Year of event':'year',
                            'Event dates':'race_day', 
                            'Event name':'race_name',
                            'Event distance/length':'race_length',
                            'Event number of finishers':'race_number_of_finishers',
                            'Athlete performance':'athlete_performance', 
                            'Athlete gender':'athlete_gender',
                            'Athlete average speed':'athlete_average_speed',
                            'Athlete ID':'athlete_id'}, inplace = True)

# %%
df2.head()
# Out:
#          year    race_day                                 race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         race_length  race_number_of_finishers athlete_performance  \
# 2539945        50km                        20             3:17:55
# 2539946        50km                        20             4:02:32
# 2539947        50km                        20             4:07:57
# 2539948        50km                        20             4:22:02
# 2539949        50km                        20             4:27:34
#
#         athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 2539945              M                 15.158       71287           29
# ...

# %%
#Reorder columns

# %%
df2.columns
# Out:
# Index(['year', 'race_day', 'race_name', 'race_length',
#        'race_number_of_finishers', 'athlete_performance', 'athlete_gender',
#        'athlete_average_speed', 'athlete_id', 'athlete_age'],
#       dtype='object')

# %%
df3 = df2[['race_day', 'race_name', 'race_length',
       'race_number_of_finishers', 'athlete_id', 'athlete_gender','athlete_age', 'athlete_performance',
       'athlete_average_speed',  'year']]
df3.head()
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2539945                        20       71287              M           29
# 2539946                        20      629508              M           39
# 2539947                        20       64838              M           21
# 2539948                        20      704450              M           37
# 2539949                        20      810281              M           43
#
#         athlete_performance  athlete_average_speed  year
# ...

# %%
#Finding 2 races that ran in 2020 - sarasota / Everglades

# %%
df3[df3['race_name'] == 'Everglades 50 Mile Ultra Run ']
# Out:
#            race_day                      race_name race_length  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591489  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# ...

# %%
#222509

# %%
df3[df3['athlete_id'] == 222509]
# Out:
#            race_day                      race_name race_length  \
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2616900  22.02.2020       Manasota Track Club 50K         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2591482                        40      222509              M           23
# 2616900                        36      222509              M           23
#
#         athlete_performance  athlete_average_speed  year
# 2591482             9:19:10                  8.634  2020
# 2616900             4:49:16                 10.371  2020

# %%
#Chart and graphs

# %%
sns.histplot(df3['race_length'])
plt.show()
# Out:
# C:\Users\HP.SXTO9\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
plt.show()
# Out:
# C:\Users\HP.SXTO9\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(df3[df3['race_length'] == '50mi']['athlete_average_speed'])
plt.show()
# Out:
# C:\Users\HP.SXTO9\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.violinplot(data = df3, x = 'race_length', y= 'athlete_average_speed', hue = 'athlete_gender',inner = 'quartile', split = True, linewidth = 1)
plt.show()

# %%
sns.lmplot(data = df3, x = 'athlete_age', y= 'athlete_average_speed', hue = 'athlete_gender')
plt.show()

# %%
#Questions I want to find out from the data

# %%
# race_day                     
# race_name                    
# race_length                  
# race_number_of_finishers      
# athlete_id                    
# athlete_gender               
# athlete_age                   
# athlete_performance          
# athlete_average_speed       
# year

# %%
#Difference in spead for the 50k, 50mi to female

# %%
#In groupby
df3.groupby(['race_length', 'athlete_gender']).agg({'athlete_average_speed':'mean'})
# Out:
#                             athlete_average_speed
# race_length athlete_gender
# 50km        F                            7.092015
#             M                            7.743376
# 50mi        F                            6.830764
#             M                            7.249766

# %%
#in pivot_table
df3.pivot_table(values= 'athlete_average_speed',index= ['race_length', 'athlete_gender'],aggfunc= 'mean')
# Out:
#                             athlete_average_speed
# race_length athlete_gender
# 50km        F                            7.092015
#             M                            7.743376
# 50mi        F                            6.830764
#             M                            7.249766

# %%
#What age groups are the best in the 50 Race (20 + races min) (Show 15)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = False).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 29           7.895574    136
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.471053     95
# 31           7.440842    139
# 38           7.420884    232
# 35           7.414633    196
# 36           7.394645    186
# 33           7.379188    149
# 22           7.367902     41
# 26           7.328584     77
# 42           7.327656    209
# 24           7.327203     74
# 34           7.307923    183
# 21           7.304658     38
# 40           7.304553    237
# 20           7.293778     27
# 39           7.283566    228
# 32           7.269518    164
# 37           7.220493    221
# 27           7.201748    119
# 41           7.185767    180
# 45           7.130667    156
# 47           7.085410    156
# 44           7.047361    180
# 51           7.014248    125
# 46           6.900326    175
# 43           6.874670    188
# 52           6.847400    130
# ...

# %%
#What age groups are the best in the 50 Race (20 + races min) (Show 20)

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean','count']).sort_values('mean', ascending = True).query('count>19')
# Out:
#                  mean  count
# athlete_age
# 60           6.227206     34
# 62           6.267564     39
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67
# 64           6.620727     22
# 50           6.671541    172
# 59           6.672072     83
# 48           6.696853    136
# 56           6.708373     67
# 53           6.724598     97
# 57           6.783205     78
# 49           6.789776    161
# 54           6.792429     84
# 55           6.814800     70
# 52           6.847400    130
# 43           6.874670    188
# 46           6.900326    175
# 51           7.014248    125
# 44           7.047361    180
# 47           7.085410    156
# 45           7.130667    156
# 41           7.185767    180
# 27           7.201748    119
# 37           7.220493    221
# 32           7.269518    164
# 39           7.283566    228
# 20           7.293778     27
# 40           7.304553    237
# 21           7.304658     38
# ...

# %%
#Season for the data -> slower in summer than winter?

#spring    3 - 5
#summer   6 - 8
#fall    0 - 11
#winter 12 - 2

#Split between tow decimals

# %%
df3['race_month'] = df3 ['race_day'].str.split('.').str.get(1).astype(int)
# Out:
# C:\Users\HP.SXTO9\AppData\Local\Temp\ipykernel_12788\2167351201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['race_month'] = df3 ['race_day'].str.split('.').str.get(1).astype(int)

# %%
df3['season'] = df3['race_month'].apply(lambda x: 'winter' if x > 11 else 'fall' if x > 8 else 'summer' if x > 5 else 'spring' if x > 2 else 'winter')
# Out:
# C:\Users\HP.SXTO9\AppData\Local\Temp\ipykernel_12788\2050553173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['season'] = df3['race_month'].apply(lambda x: 'winter' if x > 11 else 'fall' if x > 8 else 'summer' if x > 5 else 'spring' if x > 2 else 'winter')

# %%
df3.head(25)
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539950  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539951  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539952  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539953  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539954  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539955  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539956  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...

# %%
df3['season'] = df3['race_month'].apply(lambda x: 'winter' if x > 11 else 'fall' if x > 8 else 'summer' if x > 5 else 'spring' if x > 2 else 'winter')
# Out:
# C:\Users\HP.SXTO9\AppData\Local\Temp\ipykernel_12788\2050553173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['season'] = df3['race_month'].apply(lambda x: 'winter' if x > 11 else 'fall' if x > 8 else 'summer' if x > 5 else 'spring' if x > 2 else 'winter')

# %%
df3.head()
# Out:
#            race_day                                 race_name race_length  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#          race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 2539945                        20       71287              M           29
# 2539946                        20      629508              M           39
# 2539947                        20       64838              M           21
# 2539948                        20      704450              M           37
# 2539949                        20      810281              M           43
#
# ...

# %%
df3.groupby('season').agg({'athlete_average_speed': ['mean', 'count']}).sort_values(('athlete_average_speed', 'mean'), ascending=False)
# Out:
#        athlete_average_speed
#                         mean  count
# season
# spring              7.703542   3385
# winter              7.524506  11825
# fall                7.406619   8315
# summer              6.859274   2764

# %%
#50 miler only

# %%
df3.query('race_length == "50mi"').groupby('season').agg({'athlete_average_speed': ['mean', 'count']}).sort_values(('athlete_average_speed', 'mean'), ascending=False)
# Out:
#        athlete_average_speed
#                         mean count
# season
# fall                7.511585  1997
# spring              7.082557   836
# winter              7.046989  1981
# summer              6.486055   843
